# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module o Matplotlib.
# Matplotlib is a cross-platform, data visualization and graphical plotting library for Python and its numerical extension NumPy. As such, it offers a viable open source alternative to MATLAB. Developers can also use matplotlib’s APIs (Application Programming Interfaces) to embed plots in GUI applications.
# It is mainly used for data visualization and graphical plotting.
#
# Five plots:4.
# 1. line Plot
# 2. Pie Plot
# 3. Bar Plot
# 4. histogram(hist)
# 5. scatter Plot

# %% [markdown]
# # Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data plot a scatter plot.
#
# Scatter plots are the graphs that represent the relationship between two variables in a data-set. It presents dta points on a 2D plane. The independent variables  are plotted on X axis where as depenedent variables are plotted on Y axis.

# %%
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
colors = [i for i in range(50)]
plt.scatter(x,y,c = colors)
plt.title("Scatter plot")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.grid()
plt.show()

# %% [markdown]
# # Q3: Why is the subplot() function used? Draw four line plots using the subplot() function. Use the following data:
# subplot() function adds subplot to a current figure at the specified grid position.

# %%
plt.figure(figsize=[7.5, 5.5])

x = np.array([0,1,2,3,4,5])
y = np.array([0,100,200,300,400,500])
plt.subplot(121)
plt.plot(x,y,label='line1')

x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([50, 20, 40, 20, 60, 70])
plt.subplot(121)
plt.plot(x,y,label='line2')

x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([10, 20, 30, 40, 50, 60])
plt.subplot(121)
plt.plot(x,y,label='line3')

x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([200, 350, 250, 550, 450, 150])
plt.subplot(121)
plt.plot(x,y,label='line4')

plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# # Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
#
# The pictorial representation of grouped data, in the form of vertical or horizontal rectangular bars, where the lengths of the bars are equivalent to the measure of data, are known as bar graphs or bar charts.
#
# It shows the relationship between a numeric and a categoric variable.
# Each entity of the categoric variable is represented as a bar.
# The size of the bar represents its numeric value.
# The bar graph is used to compare the items between different groups over time. Bar graphs are used to measure the changes over a period of time. When the changes are larger, a bar graph is the best option to represent the data.

# %%
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

plt.figure(figsize=(14,6))
plt.subplot(121)
plt.bar(company, profit)
plt.xlabel("Company")
plt.ylabel("Profit")
plt.title("Vertical Bar Plot")
plt.subplot(122)
plt.barh(company, profit)
plt.xlabel("Profit")
plt.ylabel("Company")
plt.title("Horizontal Bar plot")
plt.show()

# %% [markdown]
# # Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
#
# When we display the data distribution in a standardized way using 5 summary – minimum, Q1 (First Quartile), median, Q3(third Quartile), and maximum, it is called a Box plot.
#
# It is used to know:
#
# The outliers and their values
# Symmetry of Data
# Tight grouping of data
# Data skewness – if, in which direction and how

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)
fig = plt.figure(figsize=(10,7))
plt.boxplot([box1, box2])
plt.show()
